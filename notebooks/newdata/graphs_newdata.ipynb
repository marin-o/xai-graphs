# %% [markdown]
# # Data preprocessing

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.api.types import union_categoricals
import sys
import os

# Get the absolute path to the parent directory containing the mj module
parent_directory = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
sys.path.insert(0, parent_directory)

# Now import from mj package
from mj import utils

# %% [markdown]
# ### Read dataset

# %%
data = pd.read_csv('../../data/processed_data/processed_data_2015_onward_mean_newdata.csv')

# %%
data.head(20)
# Out:
#      EventDate Actor1CountryCode Actor2CountryCode  GoldsteinScale_Averaged  \
# 0   2015-01-31               AFG               PAK                 1.062500
# 1   2015-01-31               AFG               USA                 1.693333
# 2   2015-01-31               AFR               BDI                -1.000000
# 3   2015-01-31               AFR               USA                 2.800000
# 4   2015-01-31               AFR               ZAF               -10.000000
# 5   2015-01-31               ARM               BGR                 3.400000
# 6   2015-01-31               AUS               ARE               -10.000000
# 7   2015-01-31               AUS               USA                 1.000000
# 8   2015-01-31               BFA               CIV                 3.400000
# 9   2015-01-31               BHR               ARE               -10.000000
# 10  2015-01-31               BLR               USA                -5.000000
# ...

# %% [markdown]
# ### Alphabetical order transformation

# %% [markdown]
# ### Remove tuples that contain the same two countries but in different order by averaging the values from both tuples (ex. AFG - PAK and PAK - AFG)

# %%
data[['Actor1CountryCode', 'Actor2CountryCode']] = \
    data[['Actor1CountryCode', 'Actor2CountryCode']].apply(
        lambda x: sorted(x), axis=1, result_type='expand'
    )

# %%
data = data.groupby(['EventDate', 'Actor1CountryCode', 'Actor2CountryCode'])[
    ['GoldsteinScale_Averaged', 'AvgTone_Averaged', 'NumMentions_averaged',
     'NumArticles_averaged']].mean().reset_index()

# %%
data.head(5)
# Out:
#     EventDate Actor1CountryCode Actor2CountryCode  GoldsteinScale_Averaged  \
# 0  2015-01-31               AFG               PAK                 1.827083
# 1  2015-01-31               AFG               USA                 2.575833
# 2  2015-01-31               AFR               BDI                -1.000000
# 3  2015-01-31               AFR               DJI                 5.200000
# 4  2015-01-31               AFR               NGA                 1.000000
#
#    AvgTone_Averaged  NumMentions_averaged  NumArticles_averaged
# 0         -0.594263              4.270833              4.270833
# 1         -1.874094              6.758333              6.758333
# 2          0.353357              5.000000              5.000000
# 3         -1.477833              3.000000              3.000000
# 4         -2.072539              6.000000              6.000000

# %% [markdown]
# ### Familiarization

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261097 entries, 0 to 261096
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   EventDate                261097 non-null  object
#  1   Actor1CountryCode        261097 non-null  object
#  2   Actor2CountryCode        261097 non-null  object
#  3   GoldsteinScale_Averaged  261097 non-null  float64
#  4   AvgTone_Averaged         261097 non-null  float64
#  5   NumMentions_averaged     261097 non-null  float64
#  6   NumArticles_averaged     261097 non-null  float64
# dtypes: float64(4), object(3)
# memory usage: 13.9+ MB

# %%
data.describe()
# Out:
#        GoldsteinScale_Averaged  AvgTone_Averaged  NumMentions_averaged  \
# count            261097.000000     261097.000000         261097.000000
# mean                  1.286537         -0.980454              5.128489
# std                   3.431721          3.771160              2.997737
# min                 -10.000000        -26.250000              1.000000
# 25%                   0.000000         -3.341902              3.083333
# 50%                   1.700000         -1.043841              4.958333
# 75%                   3.400000          1.384083              6.000000
# max                  10.000000         21.428571            275.000000
#
#        NumArticles_averaged
# count         261097.000000
# mean               5.029481
# std                2.847213
# min                1.000000
# 25%                3.000000
# 50%                4.833333
# 75%                6.000000
# max              275.000000

# %%
data.shape
# Out:
# (261097, 7)

# %%
data.to_csv('../../data/processed_data/2015_onward_duplicates_averaged_newdata.csv')

# %% [markdown]
# # Graph building

# %%
# extract nodes from data - the unique country codes
a1 = pd.Categorical(data['Actor1CountryCode'])
a2 = pd.Categorical(data['Actor2CountryCode'])
nodes = union_categoricals([a1, a2]).categories.to_list()
nodes
# Out:
# ['ABW',
#  'AFG',
#  'AFR',
#  'AGO',
#  'AIA',
#  'ALB',
#  'AND',
#  'ARE',
#  'ARG',
#  'ARM',
#  'ASA',
#  'ATG',
#  'AUS',
#  'AUT',
#  'AZE',
#  'BDI',
#  'BEL',
#  'BEN',
#  'BFA',
#  'BGD',
#  'BGR',
#  'BHR',
#  'BHS',
#  'BLR',
#  'BLZ',
#  'BMU',
#  'BOL',
#  'BRA',
#  'BRB',
#  'BRN',
#  'BTN',
#  'BWA',
#  'CAF',
#  'CAN',
#  'CAS',
#  'CAU',
#  'CHE',
#  'CHL',
#  'CHN',
#  'CIV',
#  'CMR',
#  'COD',
#  'COG',
#  'COK',
#  'COL',
#  'COM',
#  'CPV',
#  'CRB',
#  'CRI',
#  'CUB',
#  'CYM',
#  'CYP',
#  'CZE',
#  'DEU',
#  'DJI',
#  'DMA',
#  'DNK',
#  'DOM',
#  'DZA',
#  'EAF',
#  'ECU',
#  'EGY',
#  'ERI',
#  'ESP',
#  'EST',
#  'ETH',
#  'EUR',
#  'FIN',
#  'FJI',
#  'FRA',
#  'FSM',
#  'GAB',
#  'GBR',
#  'GEO',
#  'GHA',
#  'GIN',
#  'GMB',
#  'GNB',
#  'GNQ',
#  'GRC',
#  'GRD',
#  'GTM',
#  'GUY',
#  'HKG',
#  'HND',
#  'HRV',
#  'HTI',
#  'HUN',
#  'IDN',
#  'IND',
#  'IRL',
#  'IRN',
#  'IRQ',
#  'ISL',
#  'ISR',
#  'ITA',
#  'JAM',
#  'JOR',
#  'JPN',
#  'KAZ',
# ...

# %%
with open('../../data/processed_data/country_codes.txt', 'w') as file:
    for country in nodes:
        file.write(f"{country}\n")

# %%
g = nx.Graph()

# %%
g.nodes
# Out:
# NodeView(())

# %%
g.edges
# Out:
# EdgeView([])

# %% [markdown]
# # Linear combination between features:
# #### F = 0.7 * GoldsteinScale_Averaged + 0.2 * AvgTone_Averaged + 0.05 * NumMentions_averaged + 0.05 * NumArticles_averaged

# %%
filtered_data = utils.filter_data(data, '2015-01-31')

for _, row in filtered_data.iterrows():
    g.add_edge(row.iloc[1], row.iloc[2], weight=utils.linear_combination(row))

# %%
g.edges
# Out:
# EdgeView([('AFG', 'PAK'), ('AFG', 'USA'), ('PAK', 'CHN'), ('PAK', 'MEX'), ('PAK', 'SAU'), ('PAK', 'USA'), ('USA', 'AFR'), ('USA', 'AUS'), ('USA', 'BGD'), ('USA', 'BLR'), ('USA', 'BLZ'), ('USA', 'CAN'), ('USA', 'CHE'), ('USA', 'CHL'), ('USA', 'CHN'), ('USA', 'COD'), ('USA', 'COK'), ('USA', 'COL'), ('USA', 'CUB'), ('USA', 'DEU'), ('USA', 'EGY'), ('USA', 'ESP'), ('USA', 'EUR'), ('USA', 'FRA'), ('USA', 'GBR'), ('USA', 'GRC'), ('USA', 'HKG'), ('USA', 'IND'), ('USA', 'IRN'), ('USA', 'ISR'), ('USA', 'JOR'), ('USA', 'JPN'), ('USA', 'KEN'), ('USA', 'KOR'), ('USA', 'LCA'), ('USA', 'MEX'), ('USA', 'MYS'), ('USA', 'NIC'), ('USA', 'NMR'), ('USA', 'PAN'), ('USA', 'PER'), ('USA', 'PHL'), ('USA', 'RUS'), ('USA', 'SAU'), ('USA', 'SEA'), ('USA', 'SYR'), ('USA', 'TUR'), ('USA', 'UGA'), ('USA', 'YEM'), ('AFR', 'BDI'), ('AFR', 'DJI'), ('AFR', 'NGA'), ('AFR', 'SDN'), ('AFR', 'SOM'), ('AFR', 'ZAF'), ('SDN', 'KOR'), ('SDN', 'LBY'), ('SOM', 'TUR'), ('ZAF', 'CUB'), ('ZAF', 'GBR'), ('ARE', 'AUS'), ('ARE', 'BHR
# ...

# %%
for (u, v, d) in g.edges(data=True):
    print((u, v, d['weight']))
# Out:
# ('AFG', 'PAK', 1.5871889963209842)
# ('AFG', 'USA', 2.104097936284729)
# ('PAK', 'CHN', 3.4600600600600595)
# ('PAK', 'MEX', -1.702641509433962)
# ('PAK', 'SAU', -7.479220779220777)
# ('PAK', 'USA', 0.9415730337078659)
# ('USA', 'AFR', 3.8228563015312136)
# ('USA', 'AUS', 2.053976308223153)
# ('USA', 'BGD', -0.711475409836064)
# ('USA', 'BLR', -4.7401625070464)
# ('USA', 'BLZ', -0.460059171597632)
# ('USA', 'CAN', 3.4917986714358706)
# ('USA', 'CHE', 5.610451127819548)
# ('USA', 'CHL', 1.24232613908873)
# ('USA', 'CHN', -2.12096852990022)
# ('USA', 'COD', -3.9319137887959257)
# ('USA', 'COK', -0.652631578947368)
# ('USA', 'COL', -4.2126410835214445)
# ('USA', 'CUB', 3.6656794799951076)
# ('USA', 'DEU', 0.45337181049936304)
# ('USA', 'EGY', 5.364317180616739)
# ('USA', 'ESP', 1.1016074950690347)
# ('USA', 'EUR', 1.159050807271701)
# ('USA', 'FRA', -3.7283125511828077)
# ('USA', 'GBR', 1.1050185858435015)
# ('USA', 'GRC', 1.8224647887323937)
# ('USA', 'HKG', 1.3040332512315271)
# ...

# %%
# def show_graph(g):
#     # uncomment this line if you want to see the full graph
#     # esmall=[(u,v) for (u,v,d) in g.edges if d < 0]
#     elarge = [(u, v) for (u, v, d) in g.edges if d >= 0]
# 
#     plt.figure(figsize=(30, 50))
#     pos = nx.circular_layout(g)  # positions for all nodes
# 
#     # nodes
#     nx.draw_networkx_nodes(g, pos, node_size=1000)
# 
#     # edges
#     # uncomment this line if you want to see the full graph
#     # nx.draw_networkx_edges(g,pos,edgelist=esmall,
#     #                     width=6,alpha=0.5, edge_color='b',style='dashed')
# 
#     nx.draw_networkx_edges(g, pos, edgelist=elarge,
#                            width=6, edge_color='r', style='solid')
# 
#     # labels
#     nx.draw_networkx_labels(g, pos, font_size=7, font_family='sans-serif')
# 
#     plt.axis('off')
#     plt.show()  # display

# %%
utils.show_graph(g)

# %%
weights = [d['weight'] for (u, v, d) in g.edges(data=True)]
weights
# Out:
# [1.5871889963209842,
#  2.104097936284729,
#  3.4600600600600595,
#  -1.702641509433962,
#  -7.479220779220777,
#  0.9415730337078659,
#  3.8228563015312136,
#  2.053976308223153,
#  -0.711475409836064,
#  -4.7401625070464,
#  -0.460059171597632,
#  3.4917986714358706,
#  5.610451127819548,
#  1.24232613908873,
#  -2.12096852990022,
#  -3.9319137887959257,
#  -0.652631578947368,
#  -4.2126410835214445,
#  3.6656794799951076,
#  0.45337181049936304,
#  5.364317180616739,
#  1.1016074950690347,
#  1.159050807271701,
#  -3.7283125511828077,
#  1.1050185858435015,
#  1.8224647887323937,
#  1.3040332512315271,
#  3.805970149253731,
#  4.537656903765689,
#  1.216098635339204,
#  1.2020610278372579,
#  2.1973425557070816,
#  5.755329949238577,
#  3.2019022794220096,
#  0.651572327044024,
#  -1.0388131264910054,
#  -5.776190476190476,
#  3.1546759639048396,
#  3.652332439678284,
#  0.765395894428154,
#  -4.223502672824467,
#  -4.118867924528302,
#  2.9125305009815015,
#  1.8184987316871148,
# ...

# %%
# draw edge weight distribution
sns.displot(pd.DataFrame(
    {
        'weights': weights
    }, 
),
    x='weights', kind='kde'
)

# %% [markdown]
# ## Create graphs for four months

# %%
import pickle

# %%
# Ukraine-Russia War: Months for general analysis
ukraine_russia_months = [
    '2021-10-31',  # Diplomatic Efforts: Russian troop buildup begins, U.S./NATO warnings. Countries: Russia, Ukraine, USA, NATO (Germany, France, UK)
    '2021-11-30',  # Diplomatic Efforts: Escalating tensions, NATO discussions on Ukraine. Countries: Russia, Ukraine, USA, NATO (Germany, France, UK), EU
    '2021-12-31',  # Diplomatic Efforts: Russia proposes security treaties, U.S.-Russia talks. Countries: Russia, Ukraine, USA, NATO (Germany, France, UK)
    '2022-01-31',  # Diplomatic Efforts: U.S.-Russia and NATO-Russia meetings. Countries: Russia, Ukraine, USA, NATO (Germany, France, UK), EU
    '2022-02-28',  # Military Escalation: Russia invades Ukraine (Feb 24), diplomacy collapses. Countries: Russia, Ukraine, USA, NATO (Germany, France, UK)
    '2022-03-31',  # Ceasefire/Peace Talks: Early peace talks in Istanbul/Belarus, Bucha revealed. Countries: Russia, Ukraine, Turkey, Belarus, USA
    '2022-04-30',  # Humanitarian/Conflict Dynamics: Bucha fallout, Western aid surges. Countries: Russia, Ukraine, USA, NATO (Germany, France, UK), EU
    '2024-08-31',  # Military Escalation: Ukraine's Kursk incursion, shifts negotiation leverage. Countries: Russia, Ukraine, USA, NATO (Germany, France, UK)
    '2024-11-30',  # Military Escalation: Peak Russian territorial gains (725 sq km). Countries: Russia, Ukraine, USA, NATO (Germany, France, UK)
    '2025-05-31'   # Ceasefire/Peace Talks: Istanbul peace talks (May 16, 2025), prisoner swap. Countries: Russia, Ukraine, Turkey, USA
]

# Israel-Palestine War: Months for general analysis
israel_palestine_months = [
    '2023-05-31',  # Conflict Dynamics: West Bank clashes, settlement tensions. Countries: Israel, Palestine (Palestinian Authority), USA, Jordan
    '2023-06-30',  # Military Escalation: Israeli raids in Jenin, Palestinian warnings. Countries: Israel, Palestine (Hamas, Palestinian Authority), Jordan
    '2023-07-31',  # Conflict Dynamics: West Bank violence, de-escalation calls. Countries: Israel, Palestine (Palestinian Authority), USA, UN, Jordan
    '2023-08-31',  # Conflict Dynamics: Jerusalem tensions, settler violence. Countries: Israel, Palestine (Hamas, Palestinian Authority), Jordan, USA
    '2023-09-30',  # Conflict Dynamics: Pre-war skirmishes, Gaza restrictions. Countries: Israel, Palestine (Hamas), Egypt, Qatar
    '2023-10-31',  # Military Escalation: Hamas attack (Oct 7), Israel’s offensive. Countries: Israel, Palestine (Hamas), Egypt, Qatar, USA
    '2023-11-30',  # Ceasefire/Peace Talks: Brief truce, hostage releases, aid to Gaza. Countries: Israel, Palestine (Hamas), Egypt, Qatar, USA, UN
    '2024-03-31',  # Military Escalation: Intensified Israeli offensive, humanitarian crisis. Countries: Israel, Palestine (Hamas), USA, UN, Egypt
    '2024-07-31',  # Diplomatic Efforts: ICJ rules occupation unlawful, global pressure. Countries: Israel, Palestine (Palestinian Authority), USA, UN, Jordan
    '2025-01-31'   # Ceasefire/Peace Talks: Ceasefire agreement, governance talks. Countries: Israel, Palestine (Hamas, Palestinian Authority), Egypt, Qatar, USA, UN
]

# Generate graphs for all Ukraine-Russia months
# for month in ukraine_russia_months:
#     utils.create_graph_for_month(data, month, prefix='ukraine_russia')

# # Generate graphs for all Israel-Palestine months
# for month in israel_palestine_months:
#     utils.create_graph_for_month(data, month, prefix='israel_palestine')

# Prediction for Ukraine-Russia: Train on 4 months, test on 5th
ukraine_russia_predictions = [
    {
        'train': [
            '2021-11-30',  # Diplomatic Efforts: NATO discussions on Ukraine. Countries: Russia, Ukraine, USA, NATO (Germany, France, UK), EU
            '2021-12-31',  # Diplomatic Efforts: Russia’s security treaty proposals. Countries: Russia, Ukraine, USA, NATO (Germany, France, UK)
            '2022-01-31',  # Diplomatic Efforts: U.S.-Russia and NATO-Russia meetings. Countries: Russia, Ukraine, USA, NATO (Germany, France, UK), EU
            '2022-02-28'   # Military Escalation: Russia’s invasion begins. Countries: Russia, Ukraine, USA, NATO (Germany, France, UK)
        ],
        'test': '2022-03-31'  # Ceasefire/Peace Talks: Early peace talks, Bucha revealed. Predict cooperation among: Russia, Ukraine, Turkey, Belarus, USA
    },
    {
        'train': [
            '2025-01-31',  # Conflict Dynamics: Ongoing fighting, Russian advances. Countries: Russia, Ukraine, USA, NATO (Germany, France, UK)
            '2025-02-28',  # Conflict Dynamics: Ukrainian counteroffensives. Countries: Russia, Ukraine, USA, NATO (Germany, France, UK)
            '2025-03-31',  # Conflict Dynamics: Pre-talks military positioning. Countries: Russia, Ukraine, USA, NATO (Germany, France, UK)
            '2025-04-30'   # Conflict Dynamics: Lead-up to Istanbul talks. Countries: Russia, Ukraine, USA, Turkey
        ],
        'test': '2025-05-31'  # Ceasefire/Peace Talks: Istanbul talks, prisoner swap. Predict cooperation among: Russia, Ukraine, Turkey, USA
    }
]

# Prediction for Israel-Palestine: Train on 4 months, test on 5th
israel_palestine_predictions = [
    {
        'train': [
            '2023-07-31',  # Conflict Dynamics: West Bank violence, de-escalation calls. Countries: Israel, Palestine (Palestinian Authority), USA, Jordan
            '2023-08-31',  # Conflict Dynamics: Jerusalem tensions, settler violence. Countries: Israel, Palestine (Hamas, Palestinian Authority), Jordan, USA
            '2023-09-30',  # Conflict Dynamics: Pre-war skirmishes, Gaza restrictions. Countries: Israel, Palestine (Hamas), Egypt, Qatar
            '2023-10-31'   # Military Escalation: Hamas attack, Israel’s offensive. Countries: Israel, Palestine (Hamas), Egypt, Qatar, USA
        ],
        'test': '2023-11-30'  # Ceasefire/Peace Talks: Brief truce, hostage releases. Predict cooperation among: Israel, Palestine (Hamas), Egypt, Qatar, USA, UN
    },
    {
        'train': [
            '2024-09-30',  # Conflict Dynamics: Ongoing Gaza fighting. Countries: Israel, Palestine (Hamas), Egypt, Qatar, USA
            '2024-10-31',  # Conflict Dynamics: Continued military operations. Countries: Israel, Palestine (Hamas), Egypt, Qatar, USA
            '2024-11-30',  # Diplomatic Efforts: Pre-ceasefire negotiations. Countries: Israel, Palestine (Hamas, Palestinian Authority), Egypt, Qatar, USA, UN
            '2024-12-31'   # Diplomatic Efforts: Lead-up to ceasefire agreement. Countries: Israel, Palestine (Hamas, Palestinian Authority), Egypt, Qatar, USA, UN
        ],
        'test': '2025-01-31'  # Ceasefire/Peace Talks: Ceasefire, governance talks. Predict cooperation among: Israel, Palestine (Hamas, Palestinian Authority), Egypt, Qatar, USA, UN
    }
]

# Generate graphs for prediction months
for prediction in ukraine_russia_predictions:
    for month in prediction['train']:
        utils.create_graph_for_month(data, month, prefix='ukraine_russia_train')
    utils.create_graph_for_month(data, prediction['test'], prefix='ukraine_russia_test')

for prediction in israel_palestine_predictions:
    for month in prediction['train']:
        utils.create_graph_for_month(data, month, prefix='israel_palestine_train')
    utils.create_graph_for_month(data, prediction['test'], prefix='israel_palestine_test')

# %%
with open('../../data/graphs/israel_palestine_test_graph_2023-11-30.pkl', 'rb') as f:
    g = pickle.load(f)
    utils.show_graph(g)
